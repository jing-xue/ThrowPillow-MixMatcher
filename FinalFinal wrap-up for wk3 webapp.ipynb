# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolor
import matplotlib.colors as mcolor
from ast import literal_eval
from mpl_toolkits.mplot3d import Axes3D
from scipy.spatial import distance as distance

dir = os.getcwd()
home = os.path.dirname(os.path.dirname(dir)) ## 2 levels up of working directory dir

# %%
# import pallet file
palette_tuple = pd.read_csv(os.path.join(dir,r'palette_clean_hex.csv'), index_col = 0)

# reformat tuples after read_csv
# do the same for palette_tuple
palette_tuple['RGB1']=palette_tuple['RGB1'].apply(literal_eval)
palette_tuple['RGB2']=palette_tuple['RGB2'].apply(literal_eval)
palette_tuple['RGB3']=palette_tuple['RGB3'].apply(literal_eval)
palette_tuple['RGB4']=palette_tuple['RGB4'].apply(literal_eval)

print(palette_tuple.shape)
palette_tuple.head()
# Out:
# (3175, 8)
#                                    RGB1             RGB2             RGB3  \
# Up Shore                  (2, 146, 183)   (26, 200, 219)  (140, 117, 106)
# Thwarted Summer Shower    (76, 82, 112)   (246, 82, 160)   (54, 238, 224)
# Luscious Lemonade        (225, 195, 64)   (76, 215, 208)  (164, 232, 224)
# Rosettes and Cream      (216, 167, 177)  (182, 226, 211)  (250, 232, 224)
# Berry Blues                (78, 26, 61)  (207, 238, 209)   (255, 39, 104)
#
#                                    RGB4     hex1     hex2     hex3     hex4
# Up Shore                (222, 226, 236)  #0292b7  #1ac8db  #8c756a  #dee2ec
# Thwarted Summer Shower  (188, 236, 224)  #4c5270  #f652a0  #36eee0  #bcece0
# Luscious Lemonade       (248, 234, 140)  #e1c340  #4cd7d0  #a4e8e0  #f8ea8c
# Rosettes and Cream      (239, 124, 142)  #d8a7b1  #b6e2d3  #fae8e0  #ef7c8e
# Berry Blues               (5, 224, 233)  #4e1a3d  #cfeed1  #ff2768  #05e0e9

# %%
# import data with referecing palette and recommendation after yolo
data_w_yolo = pd.read_csv(os.path.join(dir, r'cropped_image_w_recommendation.csv'), index_col = 0)

data_w_yolo['match1_img'] = [data_w_yolo['index_image'][i] for i in data_w_yolo['match1']] 
data_w_yolo['match2_img'] = [data_w_yolo['index_image'][i] for i in data_w_yolo['match2']] 
data_w_yolo['match3_img'] = [data_w_yolo['index_image'][i] for i in data_w_yolo['match3']] 

data_w_yolo['match1_hex'] = [data_w_yolo['RGB_x_hex'][i] for i in data_w_yolo['match1']] 
data_w_yolo['match2_hex'] = [data_w_yolo['RGB_x_hex'][i] for i in data_w_yolo['match2']] 
data_w_yolo['match3_hex'] = [data_w_yolo['RGB_x_hex'][i] for i in data_w_yolo['match3']] 

# based off of 1534 catalog images (1555 fed into yolo and 1534 came out with detection at 0.05 threshold)
data_w_yolo.tail()
# Out:
#                              dn_crop  dn_order  box_order class_name  \
# 1544  img_1551_1807_0_Pillow.jpg.jpg      1551       1807     Pillow
# 1545  img_1552_1808_0_Pillow.jpg.jpg      1552       1808     Pillow
# 1546  img_1553_1809_0_Pillow.jpg.jpg      1553       1809     Pillow
# 1547  img_1554_1811_0_Pillow.jpg.jpg      1554       1811     Pillow
# 1548  img_1555_1812_0_Pillow.jpg.jpg      1555       1812     Pillow
#
#       class_id                        image index_image  crop_width  \
# 1544         0  Pillow_select/Page_9_60.jpg   Page_9_60         439
# 1545         0   Pillow_select/Page_9_6.jpg    Page_9_6         448
# 1546         0   Pillow_select/Page_9_7.jpg    Page_9_7         417
# 1547         0   Pillow_select/Page_9_8.jpg    Page_9_8         376
# 1548         0   Pillow_select/Page_9_9.jpg    Page_9_9         364
#
#       crop_height  crop_area  ...  match1  match2  match3  RGB_x_hex  \
# 1544          391     171649  ...     461     703     199    #e4ded4
# 1545          431     193088  ...     715      11     676    #c3401b
# 1546          370     154290  ...    1034     959     253    #675450
# 1547          276     103776  ...    1240     827     541    #e9e4de
# 1548          356     129584  ...     677     218     806    #6c6f7f
#
#       match1_img  match2_img  match3_img  match1_hex match2_hex  match3_hex
# 1544  Page_18_40  Page_22_54  Page_13_57     #405675    #988c8a     #bf868c
# 1545   Page_22_7  Page_10_23  Page_22_28     #30899c    #e9cbbe     #f0f6dc
# 1546  Page_28_43   Page_26_5   Page_14_5     #101949    #dfb1cb     #a01822
# 1547   Page_3_42  Page_24_53  Page_20_14     #fd8142    #a7e260     #6dc6d4
# 1548  Page_22_29   Page_14_1  Page_24_32     #cbd4d3    #19303e     #3c6599
#
# [5 rows x 32 columns]

# %%
# import coarse data with referecing palette and recommendation before yolo
# RGB were extracted directly from the entire image
data_no_yolo = pd.read_csv(os.path.join(dir, r'pillow_w_recommendation.csv'), index_col = 0)
# based off of 1880 catalog images (1555/1880 contains the same type/color products)
data_no_yolo.tail()
# Out:
#             Unnamed: 0                                                url  \
# index
# Page_32_15          14  https://ak1.ostkcdn.com/images/products/is/ima...
# Page_32_16          15  https://ak1.ostkcdn.com/images/products/126489...
# Page_32_17          16  https://ak1.ostkcdn.com/images/products/226390...
# Page_32_18          17  https://ak1.ostkcdn.com/images/products/284589...
# Page_32_19          18  https://ak1.ostkcdn.com/images/products/284589...
#
#                       RGB_x  Proportion_x            RGB_y  Proportion_y  \
# index
# Page_32_15  (254, 254, 254)      0.832538   (217, 165, 77)      0.167462
# Page_32_16     (43, 39, 34)      0.576574  (253, 253, 251)      0.423426
# Page_32_17   (56, 110, 128)      0.780294  (254, 254, 254)      0.219706
# Page_32_18  (243, 242, 240)      0.677009  (177, 163, 146)      0.322991
# Page_32_19  (241, 241, 240)      0.814369  (169, 155, 139)      0.185631
#
#             match1  match2  match3          palette_name  position_on_pltt  \
# index
# Page_32_15    1509    1468    1770           Morning Sun                 0
# Page_32_16     577    1675    1818          Bear at Rest                 1
# Page_32_17     462     810     419          Coffee Mates                 0
# Page_32_18    1516    1451     306  Baby Flower Clusters                 1
# Page_32_19    1202     738     516        Cuddle Weather                 2
#
#            RGB_x_hex
# index
# Page_32_15   #fefefe
# Page_32_16   #2b2722
# Page_32_17   #386e80
# Page_32_18   #f3f2f0
# Page_32_19   #f1f1f0

# %%
# make a recommender table: recommender
r1 = data_w_yolo[['dn_crop', 'image','palette_name','position_on_pltt','index_image','match1_img','match2_img','match3_img',
                  'RGB_x_hex','match1_hex','match2_hex','match3_hex']].copy()
r1.index = data_w_yolo['index_image']
r2 = data_no_yolo[['url','RGB_x_hex']].rename(index=str, columns={"RGB_x_hex": "old_hex"})

r1 = r1.rename(index=str, columns={'RGB_x_hex': 'user_hex'})
recommender = r1.join(r2, how='left')
print(recommender.shape)
recommender.head()
# Out:
# (1549, 14)
#                               dn_crop                         image  \
# index_image
# Page_10_11   img_1_1_0_Pillow.jpg.jpg  Pillow_select/Page_10_11.jpg
# Page_10_12   img_2_2_0_Pillow.jpg.jpg  Pillow_select/Page_10_12.jpg
# Page_10_13   img_3_3_0_Pillow.jpg.jpg  Pillow_select/Page_10_13.jpg
# Page_10_14   img_4_4_0_Pillow.jpg.jpg  Pillow_select/Page_10_14.jpg
# Page_10_15   img_5_5_0_Pillow.jpg.jpg  Pillow_select/Page_10_15.jpg
#
#                        palette_name  position_on_pltt index_image  match1_img  \
# index_image
# Page_10_11           Newborn Bundle                 2  Page_10_11  Page_18_31
# Page_10_12            Natural Flush                 2  Page_10_12  Page_25_17
# Page_10_13            Seaweed Sushi                 3  Page_10_13  Page_31_47
# Page_10_14           Stark Contrast                 3  Page_10_14   Page_6_59
# Page_10_15   Neutral Meeting Ground                 3  Page_10_15  Page_21_51
#
#              match2_img  match3_img user_hex match1_hex match2_hex match3_hex  \
# index_image
# Page_10_11   Page_16_29  Page_15_46  #aea294    #c44d73    #0f7b9b    #a6a92c
# Page_10_12    Page_25_9  Page_21_27  #d4524f    #50504f    #d2c0b7    #d47d7a
# Page_10_13   Page_18_11  Page_14_19  #d7d7db    #bbc6ce    #39625d    #232f3e
# Page_10_14   Page_29_29   Page_6_43  #131312    #c4c5c9    #6d6b61    #f5efdd
# Page_10_15    Page_18_4   Page_25_9  #e3e1df    #291b14    #47332c    #d2c0b7
#
#                                                            url  old_hex
# index_image
# Page_10_11   https://ak1.ostkcdn.com/images/products/185365...  #fcfbfa
# Page_10_12   https://ak1.ostkcdn.com/images/products/861039...  #fefefe
# Page_10_13   https://ak1.ostkcdn.com/images/products/235857...  #fcfcfc
# Page_10_14   https://ak1.ostkcdn.com/images/products/901271...  #fdfdfd
# Page_10_15   https://ak1.ostkcdn.com/images/products/955129...  #ebeae8

# %%
export_csv = recommender.to_csv (os.path.join(dir,r'fina_recommendation.csv'), index = True, header=True)
